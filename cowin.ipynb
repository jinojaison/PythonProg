# %%
import requests
import smtplib
import datetime

d=datetime.datetime.today().strftime('%d-%m-%Y')

# 18 or 45
age=18    

# No of people                                                  
tot=3 

# Type of vaccination : COVISHIELD, COVAXIN ...                                                
vacc="COVISHIELD"

# Pincodes list 
pincodes=['560056','560059','560060', '560074', '560098']

FromEmail="jino.johns@btech.christuniversity.in"    # From Email ID inside double quote
FromEmailPass="36862755"         # From Email ID password inside double quote
ToEmail="jinojaison01@gmail.com"  # To Email ID inside double quote


message = """From: {FromEmail}
To: {ToEmail}
Subject: Vaccine Available
"""
c=0
for k in range(len(pincodes)):
  response = requests.get("https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/calendarByPin?pincode="+str(pincodes[k])+"&date="+str(d))
  for i in range(len(response.json()["centers"])):
    for j in range(len(response.json()["centers"][i-1]["sessions"])):
      if (response.json()["centers"][i-1]["sessions"][j-1]["min_age_limit"]==age and response.json()["centers"][i-1]["sessions"][j-1]["vaccine"]==vacc and response.json()["centers"][i-1]["sessions"][j-1]["available_capacity"] >=tot):
        print(response.json()["centers"][i-1]["name"])
        print(response.json()["centers"][i-1]["sessions"][j-1]["session_id"])
        print(response.json()["centers"][i-1]["sessions"][j-1]["available_capacity"])
        print(response.json()["centers"][i-1]["sessions"][j-1]["min_age_limit"])
        print(response.json()["centers"][i-1]["sessions"][j-1]["vaccine"])
        s = smtplib.SMTP('smtp.gmail.com', 587)
        s.starttls()
        s.login(FromEmail, FromEmailPass)
        str1=response.json()["centers"][i-1]["name"]
        str2=response.json()["centers"][i-1]["sessions"][j-1]["available_capacity"]
        message= (message+ "\n" +	"Center name : " + str1 + "\n"+"Available :" + str(str2) + "\n")
        c=1

if (c==1):
  s.sendmail(FromEmail, ToEmail, message)
  print('Email sent to '+ToEmail+' From '+FromEmail)
  s.quit()
# Out:
# VIJAYA HOSPITAL
# ec4ffb12-a94c-42f2-978e-d44d0da57517
# 47
# 18
# COVISHIELD
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15944/4033241873.py in <module>
#      39         s = smtplib.SMTP('smtp.gmail.com', 587)
#      40         s.starttls()
# ---> 41         s.login(FromEmail, FromEmailPass)
#      42         str1=response.json()["centers"][i-1]["name"]
#      43         str2=response.json()["centers"][i-1]["sessions"][j-1]["available_capacity"]
#
# c:\users\jinoj\appdata\local\programs\python\python39\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     743
#     744         # We could not login successfully.  Return result of last attempt.
# --> 745         raise last_exception
#     746
#     747     def starttls(self, keyfile=None, certfile=None, context=None):
#
# c:\users\jinoj\appdata\local\programs\python\python39\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     732             method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     733             try:
# --> 734                 (code, resp) = self.auth(
#     735                     authmethod, getattr(self, method_name),
#     736                     initial_response_ok=initial_response_ok)
#
# c:\users\jinoj\appdata\local\programs\python\python39\lib\smtplib.py in auth(self, mechanism, authobject, initial_response_ok)
#     655         if code in (235, 503):
#     656             return (code, resp)
# --> 657         raise SMTPAuthenticationError(code, resp)
#     658
#     659     def auth_cram_md5(self, challenge=None):
#
# SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. Learn more at\n5.7.8  https://support.google.com/mail/?p=BadCredentials g12sm16989433wri.49 - gsmtp')

# %%
import requests
import smtplib
import datetime

d=datetime.datetime.today().strftime('%d-%m-%Y')

# 18 or 45
age=18    

# No of people                                                  
tot=3 

# Type of vaccination : COVISHIELD, COVAXIN ...                                                
vacc="COVISHIELD"

# Pincodes list 
pincodes=['560056','560059','560060', '560074', '560098']

FromEmail="jino.johns@btech.christuniversity.in"    # From Email ID inside double quote
FromEmailPass="36862755"         # From Email ID password inside double quote
ToEmail="jinojaison01@gmail.com"  # To Email ID inside double quote


message = """From: {FromEmail}
To: {ToEmail}
Subject: Vaccine Available
"""
c=0
for k in range(len(pincodes)):
  response = requests.get("https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/calendarByPin?pincode="+str(pincodes[k])+"&date="+str(d))
  for i in range(len(response.json()["centers"])):
    for j in range(len(response.json()["centers"][i-1]["sessions"])):
      if (response.json()["centers"][i-1]["sessions"][j-1]["min_age_limit"]==age and response.json()["centers"][i-1]["sessions"][j-1]["vaccine"]==vacc and response.json()["centers"][i-1]["sessions"][j-1]["available_capacity"] >=tot):
        print(response.json()["centers"][i-1]["name"])
        print(response.json()["centers"][i-1]["sessions"][j-1]["session_id"])
        print(response.json()["centers"][i-1]["sessions"][j-1]["available_capacity"])
        print(response.json()["centers"][i-1]["sessions"][j-1]["min_age_limit"])
        print(response.json()["centers"][i-1]["sessions"][j-1]["vaccine"])
        s = smtplib.SMTP('smtp.gmail.com', 587)
        s.starttls()
        s.login(FromEmail, FromEmailPass)
        str1=response.json()["centers"][i-1]["name"]
        str2=response.json()["centers"][i-1]["sessions"][j-1]["available_capacity"]
        message= (message+ "\n" +	"Center name : " + str1 + "\n"+"Available :" + str(str2) + "\n")
        c=1

if (c==1):
  s.sendmail(FromEmail, ToEmail, message)
  print('Email sent to '+ToEmail+' From '+FromEmail)
  s.quit()
# Out:
# VIJAYA HOSPITAL
# ec4ffb12-a94c-42f2-978e-d44d0da57517
# 47
# 18
# COVISHIELD
# VIJAYA HOSPITAL
# 33412cb1-b37c-46c9-8e12-370be195a253
# 45
# 18
# COVISHIELD
# VIJAYA HOSPITAL
# 5952efda-84b7-4bf5-a59b-9b978992cd00
# 55
# 18
# COVISHIELD
# VIJAYA HOSPITAL
# ed30e5d9-e8b7-426f-9125-c22410e7505f
# 56
# 18
# COVISHIELD
# VIJAYA HOSPITAL
# 2206908e-0c3c-4170-a53f-2a4043379b25
# 56
# 18
# COVISHIELD
# VIJAYA HOSPITAL
# 611429a8-2348-4615-b6c7-198ca9115c0c
# 56
# 18
# COVISHIELD
# BGS GIMS
# e889603a-8020-4df5-a6b4-f05e66b54c2a
# 50
# 18
# COVISHIELD
# MIRACLE HELATH -RR NAGAR
# 948a0d1b-191a-4aa6-baa0-76ed9dd109a5
# 58
# 18
# COVISHIELD
# Email sent to jinojaison01@gmail.com From jino.johns@btech.christuniversity.in
