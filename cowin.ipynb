# %%
import requests
import smtplib
import datetime

d=datetime.datetime.today().strftime('%d-%m-%Y')

# 18 or 45
age=18    

# No of people                                                  
tot=3 

# Type of vaccination : COVISHIELD, COVAXIN ...                                                
vacc="COVISHIELD"

# Pincodes list 
pincodes=['560056','560059','560060', '560074', '560098']

FromEmail="forpythonprog@gmail.com"    # From Email ID inside double quote
FromEmailPass="pythonpg123"         # From Email ID password inside double quote
ToEmail="jino.johns@btech.christuniversity.in"  # To Email ID inside double quote


message = """From: {FromEmail}
To: {ToEmail}
Subject: Vaccine Available
"""
c=0
for k in range(len(pincodes)):
  response = requests.get("https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/calendarByPin?pincode="+str(pincodes[k])+"&date="+str(d))
  for i in range(len(response.json()["centers"])):
    for j in range(len(response.json()["centers"][i-1]["sessions"])):
      if (response.json()["centers"][i-1]["sessions"][j-1]["min_age_limit"]==age and response.json()["centers"][i-1]["sessions"][j-1]["vaccine"]==vacc and response.json()["centers"][i-1]["sessions"][j-1]["available_capacity"] >=tot):
        print(response.json()["centers"][i-1]["name"])
        print(response.json()["centers"][i-1]["sessions"][j-1]["session_id"])
        print(response.json()["centers"][i-1]["sessions"][j-1]["available_capacity"])
        print(response.json()["centers"][i-1]["sessions"][j-1]["min_age_limit"])
        print(response.json()["centers"][i-1]["sessions"][j-1]["vaccine"])
        s = smtplib.SMTP('smtp.gmail.com', 587)
        s.starttls()
        s.login(FromEmail, FromEmailPass)
        str1=response.json()["centers"][i-1]["name"]
        str2=response.json()["centers"][i-1]["sessions"][j-1]["available_capacity"]
        message= (message+ "\n" +	"Center name : " + str1 + "\n"+"Available :" + str(str2) + "\n")
        c=1

if (c==1):
  s.sendmail(FromEmail, ToEmail, message)
  print('Email sent to '+ToEmail+' From '+FromEmail)
  s.quit()
# Out:
# UNITY LIFELINE HOSPITAL
# 12a81fc5-9a58-45b1-92c2-4f9916addb19
# 377
# 18
# COVISHIELD
# UNITY LIFELINE HOSPITAL
# e3e26d0b-227b-4f45-b92b-abe25fae48b3
# 386
# 18
# COVISHIELD
# UNITY LIFELINE HOSPITAL
# a4e05f70-552f-480a-bc85-b089b0d583d2
# 383
# 18
# COVISHIELD
# UNITY LIFELINE HOSPITAL
# eac4cee6-57d1-42cd-8edc-d7d1e3c2352e
# 386
# 18
# COVISHIELD
# UNITY LIFELINE HOSPITAL
# f8806df5-68f1-48d4-a422-f9c1f667aa1e
# 394
# 18
# COVISHIELD
# UNITY LIFELINE HOSPITAL
# 03d4bf04-0b31-4bd1-ad77-a44a2ca6f45f
# 383
# 18
# COVISHIELD
# UNITY LIFELINE HOSPITAL
# bef9f0f1-95de-49b4-bbf3-f0b20ad6c2d3
# 385
# 18
# COVISHIELD
# VIJAYA HOSPITAL
# 0c62549d-125a-42b6-9a7c-aa8ebf838b5f
# 58
# 18
# COVISHIELD
# VIJAYA HOSPITAL
# 2206908e-0c3c-4170-a53f-2a4043379b25
# 48
# 18
# COVISHIELD
# VIJAYA HOSPITAL
# 611429a8-2348-4615-b6c7-198ca9115c0c
# 58
# 18
# COVISHIELD
# VIJAYA HOSPITAL
# ec4ffb12-a94c-42f2-978e-d44d0da57517
# 37
# 18
# COVISHIELD
# VIJAYA HOSPITAL
# fa475d2d-b23d-432f-9a4c-c48a4a0c41ac
# 50
# 18
# COVISHIELD
# VIJAYA HOSPITAL
# 1dfacadd-2a7b-4489-8300-3e100f6386a5
# 60
# 18
# COVISHIELD
# SPARSH SUPER SPL YESHWANTHPUR
# f5238569-f621-4260-bf65-a4ba075bdb0e
# 499
# 18
# COVISHIELD
# BGS GIMS
# d74336db-842d-401c-b9f3-016a072617d6
# 58
# 18
# COVISHIELD
# MIRACLE HELATH -RR NAGAR
# aafa00f9-b65b-464a-b7e9-b276258cfae7
# 34
# 18
# COVISHIELD
# ATREUM HOSPITAL
# 84987325-a5dd-4e0d-b23a-5eb4fafa879b
# 169
# 18
# COVISHIELD
# Email sent to jino.johns@btech.christuniversity.in From forpythonprog@gmail.com
